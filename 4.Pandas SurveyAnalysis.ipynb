# %%
import pandas as pd

df=pd.read_csv("C:/Users/Korisnik/Desktop/DataScience/Python/Podaci-za-analizu/Anketa-2023/survey_results_public.csv")
pd.set_option("display.max_columns", 85)

df.head(10)
# Out:
#    ResponseId     Q120                                         MainBranch  \
# 0           1  I agree                                      None of these
# 1           2  I agree                     I am a developer by profession
# 2           3  I agree                     I am a developer by profession
# 3           4  I agree                     I am a developer by profession
# 4           5  I agree                     I am a developer by profession
# 5           6  I agree                     I am a developer by profession
# 6           7  I agree                     I am a developer by profession
# 7           8  I agree                     I am a developer by profession
# 8           9  I agree  I am not primarily a developer, but I write co...
# 9          10  I agree                     I am a developer by profession
#
#                Age                                         Employment  \
# 0  18-24 years old                                                NaN
# ...

# %%
df[["ConvertedCompYearly"]]
# Out:
#        ConvertedCompYearly
# 0                      NaN
# 1                 285000.0
# 2                 250000.0
# 3                 156000.0
# 4                  23456.0
# ...                    ...
# 89179                  NaN
# 89180                  NaN
# 89181                  NaN
# 89182                  NaN
# 89183                  NaN
#
# [89184 rows x 1 columns]

# %%
df["ConvertedCompYearly"].median()
# Out:
# 74963.0

# %%
#takodje korisna funkcija je i sledeca,daje nam neke vazne statisricke podatke
#Da smo napisali df.describe() dobili bi za sve kolone statisticke podatke
df[["ConvertedCompYearly"]].describe()
# Out:
#        ConvertedCompYearly
# count         4.801900e+04
# mean          1.031101e+05
# std           6.814188e+05
# min           1.000000e+00
# 25%           4.390700e+04
# 50%           7.496300e+04
# 75%           1.216410e+05
# max           7.435143e+07

# %%
df["SurveyEase"].value_counts(normalize=True)
#Normalize znaci da nam da koliko je ispiranika kako odgovorilo na ovo pitanje ali u obliku procenta
# Out:
# SurveyEase
# Easy                          0.624951
# Neither easy nor difficult    0.359175
# Difficult                     0.015874
# Name: proportion, dtype: float64

# %%
odgovori=df.groupby("SurveyEase") #ova funkcija grupise podatke u ovom slucaju na ljude koji su imali prvi,drugi ili treci odgobor

# %%
odgovori.get_group("Easy") #iz grupe da mi da smao ljude sa odgovorom Easy
# Out:
#        ResponseId     Q120                      MainBranch              Age  \
# 1               2  I agree  I am a developer by profession  25-34 years old
# 2               3  I agree  I am a developer by profession  45-54 years old
# 3               4  I agree  I am a developer by profession  25-34 years old
# 6               7  I agree  I am a developer by profession  35-44 years old
# 11             12  I agree  I am a developer by profession  25-34 years old
# ...           ...      ...                             ...              ...
# 89174       89175  I agree  I am a developer by profession  18-24 years old
# 89176       89177  I agree  I am a developer by profession  18-24 years old
# 89178       89179  I agree  I am a developer by profession  45-54 years old
# 89180       89181  I agree  I am a developer by profession  18-24 years old
# 89183       89184  I agree  I am a developer by profession  35-44 years old
#
#                                    Employment  \
# ...

# %%
#Ovo se moze odraditi i sa filterom
filt= df["SurveyEase"] == "Easy"
#A sldece sto cu da uradim jeste da vidim kolko imaju godina svi ri sto su reakli easy
#Iz cega cemo vidjet da najmladjima najlakse pada popunjavanje akete
df.loc[filt]["Age"].value_counts()
#Value counts se koristi da se izbroje odredjeni odgovori
# Out:
# Age
# 25-34 years old       20401
# 35-44 years old       12509
# 18-24 years old       10818
# 45-54 years old        5060
# Under 18 years old     2360
# 55-64 years old        2073
# 65 years or older       720
# Prefer not to say       151
# Name: count, dtype: int64

# %%
odgovori["SurveyEase"].value_counts() # A evo i broj ostalih odgovora
# Out:
# SurveyEase
# Difficult                      1374
# Easy                          54092
# Neither easy nor difficult    31088
# Name: count, dtype: int64

# %%
odgovori["ConvertedCompYearly"].median()
#Sad smo nasli medijanu plate svih koji su dali neki od odgovora... Najlakse pada onima sa najvecom platom  ahahha
#a najkomplokovanije onima sa najmanjom
# Out:
# SurveyEase
# Difficult                     59703.5
# Easy                          78207.0
# Neither easy nor difficult    69608.0
# Name: ConvertedCompYearly, dtype: float64

# %%
odgovori["ConvertedCompYearly"].median().loc["Easy"]
#Ovo na primjer ako zelimo samo easy da vidim ili ako se kolona sastoji od vise podataaka kao na primjer zemlje,ovako cemo naci odredjenu
# Out:
# 78207.0

# %%
odgovori["ConvertedCompYearly"].agg(["median", "mean"]) #Mozemo da napravimo i ovakvu tabelu
# Out:
#                              median           mean
# SurveyEase
# Difficult                   59703.5  185636.909747
# Easy                        78207.0  102933.407881
# Neither easy nor difficult  69608.0  100838.814956

# %%
#Ajde sad da uzmemo malo bolji prijmjer, napravio sam country_grp dje je grupa svih zemalja na anketi
country_grp = df.groupby(['Country'])
#Sad cemo da vidimo prosjecnu platu u Njemackoj
country_grp['ConvertedCompYearly'].median().loc['Germany']
# Out:
# 74963.0

# %%
#Takodje mozemo da vidimo kakvo je stanje srednje i medijane, sto se plata tice
country_grp['ConvertedCompYearly'].agg(["median","mean"])
# Out:
#                                        median           mean
# Country
# Afghanistan                             915.0  843636.090909
# Albania                               10741.0   29219.450000
# Algeria                                8782.0   10069.190476
# Andorra                               42836.0  120368.800000
# Angola                                 4302.0    4302.000000
# ...                                       ...            ...
# Venezuela, Bolivarian Republic of...  12000.0   23068.851852
# Viet Nam                              12763.0   20995.956140
# Yemen                                  6500.0   15089.333333
# Zambia                                 9687.0   13897.800000
# Zimbabwe                              12500.0   26740.000000
#
# [185 rows x 2 columns]

# %%
filt= df["Country"] == "India"
df.loc[filt]["LanguageHaveWorkedWith"]
#Sada sam prikazao ljude iz indije i njihove strucnosti sto se tice programskih jezika
# Out:
# 9        HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 66                                       Java;Scala;SQL
# 78                                JavaScript;TypeScript
# 82                                                  C++
# 85                   Assembly;C;C++;Java;JavaScript;SQL
#                               ...
# 89119                   Dart;HTML/CSS;JavaScript;Python
# 89121                                        Python;SQL
# 89164                Go;HTML/CSS;Java;JavaScript;Python
# 89165               C;C#;C++;Java;JavaScript;TypeScript
# 89167               Dart;HTML/CSS;JavaScript;TypeScript
# Name: LanguageHaveWorkedWith, Length: 5625, dtype: object

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
#Koristili smo apply metodu, kao i lambda funkciju od koje smo trazili da nam povratna informacija bude broj ljudi koji znaju Python
# Out:
# Country
# Afghanistan                              22
# Albania                                  19
# Algeria                                  35
# Andorra                                   5
# Angola                                    4
#                                        ...
# Venezuela, Bolivarian Republic of...     42
# Viet Nam                                174
# Yemen                                     8
# Zambia                                   11
# Zimbabwe                                 19
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
#Zanima nas koji procenar ljudi zna pajton iz koje zeblje, to cemo uraditi ovako.
country_uses_python = country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              22
# Albania                                  19
# Algeria                                  35
# Andorra                                   5
# Angola                                    4
#                                        ...
# Venezuela, Bolivarian Republic of...     42
# Viet Nam                                174
# Yemen                                     8
# Zambia                                   11
# Zimbabwe                                 19
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
#Napravicemo promjenljivu koja predstavlja ljude koji koriste pyhon, i promjenljivu koja nam kaze koliko je ljudi iz koje drzavee
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: count, Length: 185, dtype: int64

# %%
#Zatim cemo spojiti ove dvije kolone u jednu tabelu, ovom funkcijom
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
#Mora se dodati axis jer pajton automacki spaja redavoe a ne kolone
python_df
# Out:
#                                                     count  \
# Country
# United States of America                            18647
# Germany                                              7328
# India                                                5625
# United Kingdom of Great Britain and Northern Ir...   5552
# Canada                                               3507
# ...                                                   ...
# Saint Kitts and Nevis                                   1
# Marshall Islands                                        1
# Samoa                                                   1
# Central African Republic                                1
# San Marino                                              1
#
#                                                     LanguageHaveWorkedWith
# Country
# United States of America                                             10062
# Germany                                                               3686
# ...

# %%
#Oromijenicemo imena kolona da je jasnije
python_df.rename(columns={'count': 'NumRespondents', 'LanguageHaveWorkedWith': 'NumKnowsPython'}, inplace=True)
python_df
# Out:
#                                                     NumRespondents  \
# Country
# United States of America                                     18647
# Germany                                                       7328
# India                                                         5625
# United Kingdom of Great Britain and Northern Ir...            5552
# Canada                                                        3507
# ...                                                            ...
# Saint Kitts and Nevis                                            1
# Marshall Islands                                                 1
# Samoa                                                            1
# Central African Republic                                         1
# San Marino                                                       1
#
#                                                     NumKnowsPython
# Country
# United States of America                                     10062
# ...

# %%
#Sada pravimo novu kolonu i racunamo procenat
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100
python_df
# Out:
#                                                     NumRespondents  \
# Country
# United States of America                                     18647
# Germany                                                       7328
# India                                                         5625
# United Kingdom of Great Britain and Northern Ir...            5552
# Canada                                                        3507
# ...                                                            ...
# Saint Kitts and Nevis                                            1
# Marshall Islands                                                 1
# Samoa                                                            1
# Central African Republic                                         1
# San Marino                                                       1
#
#                                                     NumKnowsPython  \
# Country
# United States of America                                     10062
# ...

# %%
#Zatim mozemo sortirati zemlje od najveceg do najmanjeg procenta
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)
python_df
# Out:
#                                        NumRespondents  NumKnowsPython  \
# Country
# San Marino                                          1               1
# North Korea                                         4               4
# Samoa                                               1               1
# Liechtenstein                                       1               1
# Grenada                                             1               1
# ...                                               ...             ...
# Guinea                                              2               0
# Monaco                                              2               0
# Bahamas                                             2               0
# Niger                                               4               0
# Democratic People's Republic of Korea               2               0
#
#                                        PctKnowsPython
# Country
# ...

# %%
python_df.head(50) # Da prikazemo prvih 50
# Out:
#                                   NumRespondents  NumKnowsPython  \
# Country
# San Marino                                     1               1
# North Korea                                    4               4
# Samoa                                          1               1
# Liechtenstein                                  1               1
# Grenada                                        1               1
# Congo, Republic of the...                      2               2
# Dominica                                       2               2
# Saint Lucia                                    2               2
# Lesotho                                        4               4
# Mali                                           6               5
# Democratic Republic of the Congo               5               4
# Oman                                          11               8
# Liberia                                        3               2
# ...

# %%
python_df.loc[["Japan"]] #Da pronadjemo samo Japan
# Out:
#          NumRespondents  NumKnowsPython  PctKnowsPython
# Country
# Japan               362             188       51.933702
