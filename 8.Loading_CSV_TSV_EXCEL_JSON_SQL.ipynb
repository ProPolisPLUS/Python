# %%
import pandas as pd 

df = pd.read_csv('C:/Users/Korisnik/Desktop/DataAnalyst/Python/Podaci-za-analizu/Anketa-2023/survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('C:/Users/Korisnik/Desktop/DataAnalyst/Python/Podaci-za-analizu/Anketa-2023/survey_results_schema.csv')

pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %%
#Sada cemo napraviti filter i i prikazati ga, zatim takvu tabelu snimiti kao csv fajl
filt = (df['Country'] == 'India')
india_df = df.loc[filt]
india_df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 10          I agree  I am a developer by profession  25-34 years old
# 67          I agree  I am a developer by profession  25-34 years old
# 79          I agree  I am a developer by profession  18-24 years old
# 83          I agree  I am a developer by profession  25-34 years old
# 86          I agree  I am a developer by profession  25-34 years old
#
#                                     Employment  \
# ResponseId
# 10          Not employed, but looking for work
# 67                         Employed, full-time
# 79                         Employed, full-time
# 83                         Employed, full-time
# 86                         Employed, full-time
#
#                                       RemoteWork  \
# ResponseId
# 10                                           NaN
# 67          Hybrid (some remote, some in-person)
# 79                                        Remote
# ...

# %%
#Sada cemo snimiti csv fajl U folder
india_df.to_csv('C:/Users/Korisnik/Desktop/Newfolder/Vjezba.csv')

# %%
#Sada cemo snimiti isti fajl u formatu TSV
india_df.to_csv('C:/Users/Korisnik/Desktop/Newfolder/Vjezba.tsv', sep= "\t")
#Sep funkcija predstavlja separator, kako ce polja bit odvojena ako otvorimo u notepadu fajl
#TSV fajl se ucistava istom funkcijom kao csv, pd.read_csv

# %%
#Sada cemo snimiti isti fajl u XLSX
india_df.to_excel('C:/Users/Korisnik/Desktop/Newfolder/Vjezba.xlsx')

# %%
#Sa sledecom fnkcijom mozmeo da uvezemo EXCEL fajl

test = pd.read_excel("C:/Users/Korisnik/Desktop/Newfolder/Vjezba.xlsx")
test
# Out:
#       ResponseId     Q120                                         MainBranch  \
# 0             10  I agree                     I am a developer by profession
# 1             67  I agree                     I am a developer by profession
# 2             79  I agree                     I am a developer by profession
# 3             83  I agree                     I am a developer by profession
# 4             86  I agree                     I am a developer by profession
# ...          ...      ...                                                ...
# 5620       89120  I agree                     I am a developer by profession
# 5621       89122  I agree  I am not primarily a developer, but I write co...
# 5622       89165  I agree                     I am a developer by profession
# 5623       89166  I agree                     I am a developer by profession
# 5624       89168  I agree                     I am a developer by profession
#
# ...

# %%
#Ovako snimamo JSON fajl
india_df.to_json('C:/Users/Korisnik/Desktop/Newfolder/Vjezba.json',orient='records', lines=True)
#orient='records', lines=True radi preglednosti

# %%
#Na sledeci nacin uvozimo json fajl 
test = pd.read_json('C:/Users/Korisnik/Desktop/Newfolder/Vjezba.json', orient='records', lines=True)
test.head()
# Out:
#       Q120                      MainBranch              Age  \
# 0  I agree  I am a developer by profession  25-34 years old
# 1  I agree  I am a developer by profession  25-34 years old
# 2  I agree  I am a developer by profession  18-24 years old
# 3  I agree  I am a developer by profession  25-34 years old
# 4  I agree  I am a developer by profession  25-34 years old
#
#                            Employment                            RemoteWork  \
# 0  Not employed, but looking for work                                  None
# 1                 Employed, full-time  Hybrid (some remote, some in-person)
# 2                 Employed, full-time                                Remote
# 3                 Employed, full-time  Hybrid (some remote, some in-person)
# 4                 Employed, full-time                             In-person
#
#                            CodingActivities  \
# 0                                      None
# 1  Hobby;Contribute to open-source projects
# ...

# %%
# Na ovaj nacin se snima fajl u sql
from sqlalchemy import create_engine
import psycopg2

#engine = create_engine('postgresql://dbuser:dbpass@localhost:5432/sample_db') 

'''create_engine je funkcija iz sqlalchemy koja kreira "engine" za povezivanje s bazom podataka.
'postgresql://dbuser:dbpass@localhost:5432/sample_db' je URL koji definiše parametre 
povezivanja s PostgreSQL bazom podataka. Evo šta znače ovi delovi URL-a:
postgresql://: Specifičnost baze podataka (u ovom slučaju PostgreSQL).
dbuser:dbpass: Korisničko ime (dbuser) i lozinka (dbpass) za pristup bazi podataka.
localhost:5432: Adresa i port na kojem je PostgreSQL server pokrenut (u ovom slučaju lokalno na računaru na portu 5432).
sample_db: Naziv baze podataka kojoj se pristupa.'''
#india_df.to_sql('sample_table', engine, if_exists='replace')

'''india_df je DataFrame koji želimo sačuvati u bazi podataka.
to_sql je metoda Pandas DataFrame-a koja omogućuje pisanje DataFrame-a u tabelu u određenoj bazi podataka.
'sample_table' je naziv tabele u koju ćemo sačuvati podatke.
engine je objekat koji predstavlja konekciju s bazom podataka.
if_exists='replace' znači da, ako tabela već postoji, treba je zamijeniti novim podacima. 
Alternativno, možete postaviti if_exists='append' ako želite dodavati podatke u postojeću tabelu.'''
# Out:
# "india_df je DataFrame koji želimo sačuvati u bazi podataka.\nto_sql je metoda Pandas DataFrame-a koja omogućuje pisanje DataFrame-a u tabelu u određenoj bazi podataka.\n'sample_table' je naziv tabele u koju ćemo sačuvati podatke.\nengine je objekat koji predstavlja konekciju s bazom podataka.\nif_exists='replace' znači da, ako tabela već postoji, treba je zamijeniti novim podacima. \nAlternativno, možete postaviti if_exists='append' ako želite dodavati podatke u postojeću tabelu."

# %%
#Na ovaj nacin se uvodi sql fajl

#sql_df = pd.read_sql('sample_table', engine, index_col='Respondent')
#sql_df.head()

# %%
#Na ovaj nacin se ucitava sql_query fajl
#sql_df = pd.read_sql_query('SELECT * FROM sample_table', engine, index_col='Respondent')
'''pd.read_sql_query je funkcija Pandas-a koja omogućava izvršavanje SQL upita na određenom SQL backend-u (u ovom slučaju, PostgreSQL) i čitanje rezultata u DataFrame.
'SELECT * FROM sample_table' je SQL upit koji bira sve kolone (*) iz tabele 'sample_table'.
engine je objekat koji predstavlja konekciju s bazom podataka.
index_col='Respondent' postavlja kolonu 'Respondent' kao indeks DataFrame-a. To znači da će ta kolona biti korišćena kao indeks u DataFrame-u.'''
#sql_df.head()
