# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use("fivethirtyeight")

x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11, x12, x13, x14, x15 = 0.0, 0.1, 0, 10.3, 0.6, 0.4, 0.35, 0.37, 0.5, 0.3, 0.33, 0.36, 0.5, 0.55, 1
y1, y2, y3, y4, y5, y6, y7, y8, y9, y10, y11, y12, y13, y14, y15 = 0.11, 0.25, 0.5, 0.6, 0.75, 1.2, 1.3, 1.4, 1.6, 1.7, 1.8, 1.9, 2.0, 2.0, 2.1
marker = ["^","^","^","^","D","o","s","s","s","D","D","D","o","o","o"]
legends = ["HTC1","HTC2","HTC3","Py1","Py2","Py3","HTC4","HTC5","HTC6","Lignite","Peat","Coal","3POMSW","3POMWW","2POMW"]
for i in range(1,15):
    x_var = locals()[f'x{i}'] #pretvoreno u x1,x2,x3
    y_var = locals()[f'y{i}']
    plt.scatter(x_var, y_var, s=100,ec="Black",lw=1, marker=marker[i], label=legends[i])


plt.xlim(-0.5,2.5)
plt.ylim(-0.5,2.5)
plt.xlabel("O/C")
plt.ylabel("H/C")

plt.tight_layout()
plt.legend(fontsize='small')

plt.show()
