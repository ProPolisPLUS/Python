# %%
import matplotlib.pyplot as plt
import pandas as pd

#plt.style.use("fivethirtyeight")  #dobar stil
plt.xkcd()



df = pd.read_csv("C:/Users/Nikola/Desktop/Nikola-Programi/CSV-za-vjezbu/CC-python-pandas-matplotlib-master/scottish_hills.csv")
df1=df.head(10)
x = df1.HillName
y = df1.Height
z = df1.Longitude


sr = [(sum(y))/10]*10






plt.figure(figsize=(27,6))
plt.plot(x,sr, color="green", label="Srednja visina")
plt.plot(x,y, marker=".", color="Blue", ms=15, mfc="black", label="Visina")
plt.title("Grafik odstupajna planina od srednje visine")
plt.xlabel("Imena planina")
plt.ylabel("Visina")
plt.ylim(800,1200)
plt.grid(True) # Mreza
plt.legend()
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# ...
